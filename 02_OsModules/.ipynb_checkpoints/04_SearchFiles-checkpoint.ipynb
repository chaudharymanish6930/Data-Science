# %%
import os

folders = os.listdir("data Files")

print(folders)

for folder in folders:
    print(folder)
    print(os.listdir(f"data Files/{folder}"))
# Out:
# ['.ipynb_checkpoints', 'Day1', 'Day10', 'Day2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7', 'Day8', 'Day9', 'Target 1', 'Target 10', 'Target 2', 'Target 3', 'Target 4', 'Target 5', 'Target 6', 'Target 7', 'Target 8', 'Target 9']
# .ipynb_checkpoints
# []
# Day1
# []
# Day10
# []
# Day2
# []
# Day3
# []
# Day4
# []
# Day5
# []
# Day6
# []
# Day7
# []
# Day8
# []
# Day9
# []
# Target 1
# ['.ipynb_checkpoints', 'myself.txt']
# Target 10
# []
# Target 2
# []
# Target 3
# []
# Target 4
# ['.ipynb_checkpoints', 'myfriends.txt']
# Target 5
# []
# Target 6
# []
# Target 7
# []
# Target 8
# []
# Target 9
# []
