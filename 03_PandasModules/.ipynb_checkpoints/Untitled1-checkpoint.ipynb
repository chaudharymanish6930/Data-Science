# %%
import pandas as pd
df = pd.read_csv("mycsvfile.csv")
df
# Out:
#        Name  age classs grade gender
# 0    shivam    3   12th     a      f
# 1     rohit    2    8th     b      m
# 2    chetan   12    6th     c      m
# 3   asshish   32    9th     b      m
# 4     mohit   12   10th     d      m
# 5   asshmit   12    4th     e      m
# 6     tahsu    1   12th     a      f
# 7     priya   23    5th     b      f
# 8    sweety    4    7th     d      f
# 9    cheery   35    9th     b      f
# 10   candy    65    4th     e      f
# 11    chiku    4    8th     c      m
# 12    mohit   67    4th     f      m

# %%
import pandas as pd
df = pd.read_csv("mycsvfile.csv")
df
# Out:
#        Name  age classs grade gender
# 0    shivam    3   12th     a      f
# 1     rohit    2    8th     b      m
# 2    chetan   12    6th     c      m
# 3   asshish   32    9th     b      m
# 4     mohit   12   10th     d      m
# 5   asshmit   12    4th     e      m
# 6     tahsu    1   12th     a      f
# 7     priya   23    5th     b      f
# 8    sweety    4    7th     d      f
# 9    cheery   35    9th     b      f
# 10   candy    65    4th     e      f
# 11    chiku    4    8th     c      m
# 12    mohit   67    4th     f      m
