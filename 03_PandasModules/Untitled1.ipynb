# %%
import pandas as pd

# %%
df= pd.read_csv("LaptopData.csv")

# %%
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512             17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256             13.3
# 2       Asus      Gram     Apple M1     32        128             13.3
# 3      Apple      Gram     Intel i3      4        512             11.6
# 4      Apple    Galaxy     Apple M2      8        256             15.6
# ..       ...       ...          ...    ...        ...              ...
# 163       LG  Inspiron     Apple M1     32        128             11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba    Aspire     Intel i3     16       1024             14.0
# 166     Dell   ZenBook     Intel i5      8        256             13.3
# 167  Toshiba      Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 0       NVIDIA MX350      1099
# 1         AMD Radeon       972
# ...

# %% [markdown]
# ## 1 Creating a Conditonal Column from more Than 2 choice : np.select()

# %%
import numpy as np

# %%
conditions = [
    df["Price_USD"] > 3000,
    (df["Price_USD"] > 2000) & (df["Price_USD"] <= 3000),
    (df["Price_USD"] > 800) & (df["Price_USD"] <= 2000),
    df["Price_USD"] <= 800
]

values = ["Too Expensive", "Expensive", "Affordable", "Cheap"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 conditions = [
# ----> 2     df["Price_USD"] > 3000,
#       3     (df["Price_USD"] > 2000) & (df["Price_USD"] <= 3000),
#       4     (df["Price_USD"] > 800) & (df["Price_USD"] <= 2000),
#       5     df["Price_USD"] <= 800
#       6 ]
#       8 values = ["Too Expensive", "Expensive", "Affordable", "Cheap"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ...

# %%
import numpy as np

conditions = [
    df["Price_USD"] > 3000,
    (df["Price_USD"] > 2000) & (df["Price_USD"] <= 3000),
    (df["Price_USD"] > 800) & (df["Price_USD"] <= 2000),
    df["Price_USD"] <= 800
]

values = ["Too Expensive", "Expensive", "Affordable", "Cheap"]

df["Price_Category"] = np.select(conditions, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import numpy as np
#       3 conditions = [
# ----> 4     df["Price_USD"] > 3000,
#       5     (df["Price_USD"] > 2000) & (df["Price_USD"] <= 3000),
#       6     (df["Price_USD"] > 800) & (df["Price_USD"] <= 2000),
#       7     df["Price_USD"] <= 800
#       8 ]
#      10 values = ["Too Expensive", "Expensive", "Affordable", "Cheap"]
#      12 df["Price_Category"] = np.select(conditions, values)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# ...
