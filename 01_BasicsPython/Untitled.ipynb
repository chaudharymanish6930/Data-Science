# %%
print("divmod(9, 2):", divmod(9, 2))
# Out:
# divmod(9, 2): (4, 1)

# %%
print("divmod(15, 4):", divmod(178, 4))
# Out:
# divmod(15, 4): (44, 2)

# %%
# def is_even(n):
#     return n % 2 == 0
print("filter(is_even, [1,2,3,4]):", list(filter( [1,2,3,4])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # def is_even(n):
#       2 #     return n % 2 == 0
# ----> 3 print("filter(is_even, [1,2,3,4]):", list(filter( [1,2,3,4])))
#
# TypeError: filter expected 2 arguments, got 1
