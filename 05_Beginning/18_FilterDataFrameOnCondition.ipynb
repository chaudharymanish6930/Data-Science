# %%
import pandas as pd

# %%
df = pd.read_csv("laptop_price.csv")

# %%
df
# Out:
#                                Model    Company Screen Size   RAM    Storage  \
# 0                MacBook Air 13 (M4)      Apple   13 inches  16GB  256GB SSD
# 1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
# 2             Dell 14 Plus (DB14250)       Dell   14 inches  16GB    1TB SSD
# 3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
# 4             HP EliteBook Ultra G1i         HP   14 inches  32GB    1TB SSD
# 5         HP Pavilion Plus 14 (2025)         HP   14 inches  16GB  512GB SSD
# 6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
# 7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
# 8      Asus Zenbook 14 OLED (UM3406)       Asus   14 inches  16GB    1TB SSD
# 9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
# 10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
# ...

# %%
df.head(5)
# Out:
#                     Model Company Screen Size   RAM    Storage  \
# 0     MacBook Air 13 (M4)   Apple   13 inches  16GB  256GB SSD
# 1     MacBook Pro 14 (M4)   Apple   14 inches  24GB    1TB SSD
# 2  Dell 14 Plus (DB14250)    Dell   14 inches  16GB    1TB SSD
# 3      Dell XPS 13 (9350)    Dell   13 inches  16GB  512GB SSD
# 4  HP EliteBook Ultra G1i      HP   14 inches  32GB    1TB SSD
#
#             Processor    Graphics  Price (USD)  Battery Life
# 0                  M4  Integrated          999            18
# 1              M4 Pro  Integrated         1599            16
# 2  Intel Core Ultra 7  Integrated          899            13
# 3  Intel Core Ultra 7  Integrated         1199            15
# 4  Intel Core Ultra 7  Integrated         1499            19

# %% [markdown]
# ## filter the dataframe on based conditions

# %%
# find which rows have "Apple" in the "Company" column
df["Company"] == "Apple"
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: Company, dtype: bool

# %%
# now, check it RAM of the laptops
# all are string here so, please write in double quotes
df["RAM"]=="16GB"
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: RAM, dtype: bool

# %%
# filter dataframe based on condition
df[df["Company"]=="Apple"]
# Out:
#                  Model Company Screen Size   RAM    Storage Processor  \
# 0  MacBook Air 13 (M4)   Apple   13 inches  16GB  256GB SSD        M4
# 1  MacBook Pro 14 (M4)   Apple   14 inches  24GB    1TB SSD    M4 Pro
#
#      Graphics  Price (USD)  Battery Life
# 0  Integrated          999            18
# 1  Integrated         1599            16

# %%
# verify which companies in the "Company" column with value_counts()
df[df['Company']=="Lenovo"].value_counts("Company")
# Out:
# Company
# Lenovo    2
# Name: count, dtype: int64

# %%
df[df['Company']=="Apple"].value_counts("Company")
# Out:
# Company
# Apple    2
# Name: count, dtype: int64

# %% [markdown]
# ## 1.2 Exercise

# %%
# find which rows don't have  "HP" in the "Company" column
df[df["Company"]!="HP"]
# Out:
#                                Model    Company Screen Size   RAM    Storage  \
# 0                MacBook Air 13 (M4)      Apple   13 inches  16GB  256GB SSD
# 1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
# 2             Dell 14 Plus (DB14250)       Dell   14 inches  16GB    1TB SSD
# 3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
# 6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
# 7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
# 8      Asus Zenbook 14 OLED (UM3406)       Asus   14 inches  16GB    1TB SSD
# 9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
# 10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
# 11           Acer Swift Go 16 (2025)       Acer   16 inches  16GB    1TB SSD
#
#              Processor         Graphics  Price (USD)  Battery Life
# ...

# %%
[df["Company"]!="HP"]
# Out:
# [0      True
#  1      True
#  2      True
#  3      True
#  4     False
#  5     False
#  6      True
#  7      True
#  8      True
#  9      True
#  10     True
#  11     True
#  Name: Company, dtype: bool]

# %%
# filter dataframe based on condition
# all company except "HP"
df[df["Company"]!="HP"]
# Out:
#                                Model    Company Screen Size   RAM    Storage  \
# 0                MacBook Air 13 (M4)      Apple   13 inches  16GB  256GB SSD
# 1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
# 2             Dell 14 Plus (DB14250)       Dell   14 inches  16GB    1TB SSD
# 3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
# 6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
# 7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
# 8      Asus Zenbook 14 OLED (UM3406)       Asus   14 inches  16GB    1TB SSD
# 9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
# 10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
# 11           Acer Swift Go 16 (2025)       Acer   16 inches  16GB    1TB SSD
#
#              Processor         Graphics  Price (USD)  Battery Life
# ...

# %%
df["Company"].value_counts()
# Out:
# Company
# Apple        2
# Dell         2
# HP           2
# Lenovo       2
# Asus         2
# Microsoft    1
# Acer         1
# Name: count, dtype: int64

# %%
df[df["Company"] != "HP"].value_counts("Company")
# Out:
# Company
# Apple        2
# Asus         2
# Lenovo       2
# Dell         2
# Acer         1
# Microsoft    1
# Name: count, dtype: int64

# %% [markdown]
# # 1.2 Exercise

# %%
# check find laptops with ram greater than 16
df["Price (USD)"]>1000
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# Name: Price (USD), dtype: bool

# %%
df[df["Price (USD)"]>1000]
# Out:
#                                Model    Company Screen Size   RAM    Storage  \
# 1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
# 3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
# 4             HP EliteBook Ultra G1i         HP   14 inches  32GB    1TB SSD
# 6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
# 7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
# 9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
# 10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
#
#              Processor         Graphics  Price (USD)  Battery Life
# 1               M4 Pro       Integrated         1599            16
# 3   Intel Core Ultra 7       Integrated         1199            15
# 4   Intel Core Ultra 7       Integrated         1499            19
# 6   Intel Core Ultra 7       Integrated         1799            20
# ...

# %%
# with all information
[df[df["Price (USD)"]>1000]]
# Out:
# [                               Model    Company Screen Size   RAM    Storage  \
#  1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
#  3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
#  4             HP EliteBook Ultra G1i         HP   14 inches  32GB    1TB SSD
#  6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
#  7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
#  9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
#  10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
#
#               Processor         Graphics  Price (USD)  Battery Life
#  1               M4 Pro       Integrated         1599            16
#  3   Intel Core Ultra 7       Integrated         1199            15
#  4   Intel Core Ultra 7       Integrated         1499            19
#  6   Intel Core Ultra 7       Integrated         1799            20
# ...

# %%
df[df["Price (USD)"]>1000]
# Out:
#                                Model    Company Screen Size   RAM    Storage  \
# 1                MacBook Pro 14 (M4)      Apple   14 inches  24GB    1TB SSD
# 3                 Dell XPS 13 (9350)       Dell   13 inches  16GB  512GB SSD
# 4             HP EliteBook Ultra G1i         HP   14 inches  32GB    1TB SSD
# 6   Lenovo ThinkPad X1 Carbon Gen 13     Lenovo   14 inches  32GB    1TB SSD
# 7                   Lenovo Legion 5i     Lenovo   16 inches  16GB    1TB SSD
# 9              Asus ROG Zephyrus G14       Asus   14 inches  32GB    1TB SSD
# 10     Surface Laptop 7th Edition 15  Microsoft   15 inches  16GB  512GB SSD
#
#              Processor         Graphics  Price (USD)  Battery Life
# 1               M4 Pro       Integrated         1599            16
# 3   Intel Core Ultra 7       Integrated         1199            15
# 4   Intel Core Ultra 7       Integrated         1499            19
# 6   Intel Core Ultra 7       Integrated         1799            20
# ...

# %%
# laptop check the less than 1000 price
df[df["Price (USD)"]<1000]
# Out:
#                             Model Company Screen Size   RAM    Storage  \
# 0             MacBook Air 13 (M4)   Apple   13 inches  16GB  256GB SSD
# 2          Dell 14 Plus (DB14250)    Dell   14 inches  16GB    1TB SSD
# 5      HP Pavilion Plus 14 (2025)      HP   14 inches  16GB  512GB SSD
# 8   Asus Zenbook 14 OLED (UM3406)    Asus   14 inches  16GB    1TB SSD
# 11        Acer Swift Go 16 (2025)    Acer   16 inches  16GB    1TB SSD
#
#              Processor    Graphics  Price (USD)  Battery Life
# 0                   M4  Integrated          999            18
# 2   Intel Core Ultra 7  Integrated          899            13
# 5   Intel Core Ultra 5  Integrated          799            12
# 8       AMD Ryzen AI 9  Integrated          799            14
# 11  Intel Core Ultra 7  Integrated          999            12
