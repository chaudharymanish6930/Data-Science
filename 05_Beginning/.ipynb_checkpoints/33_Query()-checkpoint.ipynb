# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv("InternationalCricketor.csv")
# set index 
df.set_index("Player Name", inplace=True)
# select columns
df = df[["Country", "Matches", "Runs", "Wickets", "Innings"]]
df
# Out:
#                        Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli              India      302  13906        4      289
# Rohit Sharma             India      262  10709        8      256
# Babar Azam            Pakistan      120   5084        1      120
# Steve Smith          Australia      195   9449        0      182
# Joe Root               England      171   7479        1      167
# ...                        ...      ...    ...      ...      ...
# Mashrafe Mortaza    Bangladesh      220   1787      270      144
# Mehidy Hasan Miraz  Bangladesh       78    803       78       49
# Liton Das           Bangladesh       70   2231        0       69
# Imrul Kayes         Bangladesh       78   2434        0       78
# Soumya Sarkar       Bangladesh       64   1768        0       60
#
# [197 rows x 5 columns]

# %% [markdown]
# # 1 query()

# %%
# select players older than 34
df.query("Runs>9000")
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli                  India      302  13906        4      289
# Rohit Sharma                 India      262  10709        8      256
# Steve Smith              Australia      195   9449        0      182
# AB de Villiers        South Africa      228  10014        3      218
# Chris Gayle            West Indies      301  10562       20      294
# Ricky Ponting            Australia      375  13704        3      365
# Adam Gilchrist           Australia      287   9619        0      279
# Kumar Sangakkara         Sri Lanka      404  14234        0      380
# Mahela Jayawardene       Sri Lanka      448  12650        2      418
# Sanath Jayasuriya        Sri Lanka      445  13430      323      433
# Tillakaratne Dilshan     Sri Lanka      330  10290       39      303
# Sachin Tendulkar             India      463  18426      154      452
# ...

# %%
# exercise: write the quivalent boolean slicing
df[df["Runs"]>9000]
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli                  India      302  13906        4      289
# Rohit Sharma                 India      262  10709        8      256
# Steve Smith              Australia      195   9449        0      182
# AB de Villiers        South Africa      228  10014        3      218
# Chris Gayle            West Indies      301  10562       20      294
# Ricky Ponting            Australia      375  13704        3      365
# Adam Gilchrist           Australia      287   9619        0      279
# Kumar Sangakkara         Sri Lanka      404  14234        0      380
# Mahela Jayawardene       Sri Lanka      448  12650        2      418
# Sanath Jayasuriya        Sri Lanka      445  13430      323      433
# Tillakaratne Dilshan     Sri Lanka      330  10290       39      303
# Sachin Tendulkar             India      463  18426      154      452
# ...

# %%
# select players run more than 10000 from india
df.query("Runs>10000 and Country=='India'")
# Out:
#                  Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli        India      302  13906        4      289
# Rohit Sharma       India      262  10709        8      256
# Sachin Tendulkar   India      463  18426      154      452
# Sourav Ganguly     India      311  11363      100      300
# Rahul Dravid       India      344  10889        4      318
# MS Dhoni           India      350  10773        0      297

# %%
# boolean slicing
df[(df["Runs"] > 10000) & (df["Country"] == "India")]
# Out:
#                  Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli        India      302  13906        4      289
# Rohit Sharma       India      262  10709        8      256
# Sachin Tendulkar   India      463  18426      154      452
# Sourav Ganguly     India      311  11363      100      300
# Rahul Dravid       India      344  10889        4      318
# MS Dhoni           India      350  10773        0      297

# %%
# add not operator to the first example
df.query("not(Runs>9000)")
# Out:
#                          Country  Matches  Runs  Wickets  Innings
# Player Name
# Babar Azam              Pakistan      120  5084        1      120
# Joe Root                 England      171  7479        1      167
# Kane Williamson      New Zealand      167  6894        1      162
# David Warner           Australia      169  7074        0      168
# Quinton de Kock     South Africa      155  6446        0      152
# ...                          ...      ...   ...      ...      ...
# Mashrafe Mortaza      Bangladesh      220  1787      270      144
# Mehidy Hasan Miraz    Bangladesh       78   803       78       49
# Liton Das             Bangladesh       70  2231        0       69
# Imrul Kayes           Bangladesh       78  2434        0       78
# Soumya Sarkar         Bangladesh       64  1768        0       60
#
# [178 rows x 5 columns]

# %%
# exercise: Write the equivalent boolean slicing
df[~(df["Runs"] > 9000)]
# Out:
#                          Country  Matches  Runs  Wickets  Innings
# Player Name
# Babar Azam              Pakistan      120  5084        1      120
# Joe Root                 England      171  7479        1      167
# Kane Williamson      New Zealand      167  6894        1      162
# David Warner           Australia      169  7074        0      168
# Quinton de Kock     South Africa      155  6446        0      152
# ...                          ...      ...   ...      ...      ...
# Mashrafe Mortaza      Bangladesh      220  1787      270      144
# Mehidy Hasan Miraz    Bangladesh       78   803       78       49
# Liton Das             Bangladesh       70  2231        0       69
# Imrul Kayes           Bangladesh       78  2434        0       78
# Soumya Sarkar         Bangladesh       64  1768        0       60
#
# [178 rows x 5 columns]

# %%
# this is used to find run and above the 10000
df.query("Runs/10 > 1000")
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli                  India      302  13906        4      289
# Rohit Sharma                 India      262  10709        8      256
# AB de Villiers        South Africa      228  10014        3      218
# Chris Gayle            West Indies      301  10562       20      294
# Ricky Ponting            Australia      375  13704        3      365
# Kumar Sangakkara         Sri Lanka      404  14234        0      380
# Mahela Jayawardene       Sri Lanka      448  12650        2      418
# Sanath Jayasuriya        Sri Lanka      445  13430      323      433
# Tillakaratne Dilshan     Sri Lanka      330  10290       39      303
# Sachin Tendulkar             India      463  18426      154      452
# Sourav Ganguly               India      311  11363      100      300
# Rahul Dravid                 India      344  10889        4      318
# ...

# %%
# this is also boolean slicing
# df[(df["Runs"/10]>1000)]
df[(df["Runs"] / 10) > 1000]
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli                  India      302  13906        4      289
# Rohit Sharma                 India      262  10709        8      256
# AB de Villiers        South Africa      228  10014        3      218
# Chris Gayle            West Indies      301  10562       20      294
# Ricky Ponting            Australia      375  13704        3      365
# Kumar Sangakkara         Sri Lanka      404  14234        0      380
# Mahela Jayawardene       Sri Lanka      448  12650        2      418
# Sanath Jayasuriya        Sri Lanka      445  13430      323      433
# Tillakaratne Dilshan     Sri Lanka      330  10290       39      303
# Sachin Tendulkar             India      463  18426      154      452
# Sourav Ganguly               India      311  11363      100      300
# Rahul Dravid                 India      344  10889        4      318
# ...

# %%
# last tasks
# select player that whose had played more than 200 innings

# check the data types
df.dtypes

# cover "dob" column to datetime type
df["dob"] = df["dob"].dtype("datetime64")

# query
df.query("dob.dt.year>1990")

# also write boolean slicing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # last tasks
#       2 # select player that whose had played more than 200 innings
#       3
#       4 # check the data types
# ----> 5 df.dtypes
#       7 # cover "dob" column to datetime type
#       8 df["dob"] = df["dob"].dtype("datetime64")
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# Country    object
# Matches     int64
# Runs        int64
# Wickets     int64
# Innings     int64
# dtype: object
