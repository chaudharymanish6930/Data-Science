# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv("InternationalCricketor.csv")
# set index 
df.set_index("Player Name", inplace=True)
# select columns
df = df[["Country", "Matches", "Runs", "Wickets", "Innings"]]
df
# Out:
#                        Country  Matches   Runs  Wickets  Innings
# Player Name
# Virat Kohli              India      302  13906        4      289
# Rohit Sharma             India      262  10709        8      256
# Babar Azam            Pakistan      120   5084        1      120
# Steve Smith          Australia      195   9449        0      182
# Joe Root               England      171   7479        1      167
# ...                        ...      ...    ...      ...      ...
# Mashrafe Mortaza    Bangladesh      220   1787      270      144
# Mehidy Hasan Miraz  Bangladesh       78    803       78       49
# Liton Das           Bangladesh       70   2231        0       69
# Imrul Kayes         Bangladesh       78   2434        0       78
# Soumya Sarkar       Bangladesh       64   1768        0       60
#
# [197 rows x 5 columns]

# %% [markdown]
# # 1 Sample()

# %%
# etract 10 random elements from the "Country" column
df["Country"].sample(10)
# Out:
# Player Name
# Shai Hope          West Indies
# David Willey           England
# Matthew Hayden       Australia
# Tabraiz Shamsi    South Africa
# Graeme Swann           England
# Kieron Pollard     West Indies
# Lorcan Tucker          Ireland
# Andy Flower           Zimbabwe
# Adam Gilchrist       Australia
# Asghar Afghan      Afghanistan
# Name: Country, dtype: object

# %%
df["Country"].sample(10, random_state=99)
# random state have random players
# Out:
# Player Name
# Harbhajan Singh            India
# Sanath Jayasuriya      Sri Lanka
# Brydon Carse             England
# James Vince              England
# Mahmudullah           Bangladesh
# John Mooney              Ireland
# Heath Streak            Zimbabwe
# Liam Plunkett            England
# Chris Gayle          West Indies
# Brian Lara           West Indies
# Name: Country, dtype: object

# %%
df["Country"].sample(10, random_state=9)
# random state have random players
# Out:
# Player Name
# Rassie van der Dussen    South Africa
# Ibrahim Zadran            Afghanistan
# Abdul Razzaq                 Pakistan
# Mohammad Nabi             Afghanistan
# William Porterfield           Ireland
# Sean Williams                Zimbabwe
# Nicholas Pooran           West Indies
# Dwayne Bravo              West Indies
# Aaron Finch                 Australia
# Azmatullah Omarzai        Afghanistan
# Name: Country, dtype: object

# %%
# extract a random 20% sample of the dataframe
df.sample(frac=0.2)
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Kyle Mills             New Zealand      170   1047      240      101
# Eoin Morgan                England      248   6933        0      231
# Herschelle Gibbs      South Africa      248   8094        0      240
# Wasim Akram               Pakistan      356   3717      502      280
# Jonny Bairstow             England      100   3011        0       94
# Nasser Hussain             England       88   2332        0       79
# Alzarri Joseph         West Indies       39     69       48       13
# Curtis Campher             Ireland       15    225        7       12
# Mashrafe Mortaza        Bangladesh      220   1787      270      144
# Graeme Cremer             Zimbabwe       96    744      119       66
# Tamim Iqbal             Bangladesh      241   8313        0      239
# Sanath Jayasuriya        Sri Lanka      445  13430      323      433
# ...

# %%
df.sample(frac=0.2, random_state=12)
# Out:
#                              Country  Matches   Runs  Wickets  Innings
# Player Name
# Wayne Parnell           South Africa       34     89       22       12
# Martin Guptill           New Zealand      170   6521        0      165
# Dwayne Bravo             West Indies      164   1463       66       99
# Mushfiqur Rahim           Bangladesh      236   7088        0      220
# Fakhar Zaman                Pakistan       72   2599        0       70
# Kevin O'Brien                Ireland      148   2959       21      129
# Afsar Zazai              Afghanistan       18    206        0       15
# Mohammad Nabi            Afghanistan      125   2372       52       95
# David Warner               Australia      169   7074        0      168
# Tamim Iqbal               Bangladesh      163   6898        0      162
# Carl Hooper              West Indies      227   5761      193      206
# Nicholas Pooran          West Indies       80   1401        0       68
# ...

# %%
# upsample: increase the sampling rate -> frac>1
# note: replace parameter has to be True for frac parameter>1)
df.sample(frac=2, replace=True)
# Out:
#                        Country  Matches   Runs  Wickets  Innings
# Player Name
# Rahul Dravid             India      344  10889        4      318
# Alzarri Joseph     West Indies       39     69       48       13
# Mujeeb Ur Rahman   Afghanistan       64    294       60       36
# Mustafizur Rahman   Bangladesh       70     96      103       39
# David Willey           England       40    250       22       22
# ...                        ...      ...    ...      ...      ...
# Mitchell Starc       Australia       99    571      195       57
# John Mooney            Ireland       66    560       34       42
# Paul Stirling          Ireland      149   5334        2      145
# Liton Das           Bangladesh       70   2231        0       69
# Babar Azam            Pakistan      120   5084        1      120
#
# [394 rows x 5 columns]

# %%
df.sample(frac=2, replace=True, random_state=1)
# Out:
#                            Country  Matches   Runs  Wickets  Innings
# Player Name
# Azmatullah Omarzai     Afghanistan       22    294       11       17
# Jacques Kallis        South Africa      328  11579      273      314
# Brydon Carse               England        4     12        3        2
# Marlon Samuels         West Indies      207   5606       89      196
# Harbhajan Singh              India      236   1237      269      128
# ...                            ...      ...    ...      ...      ...
# Herschelle Gibbs      South Africa      248   8094        0      240
# Ian Bell                   England      161   5416        0      157
# Muttiah Muralitharan     Sri Lanka      350    674      534      162
# Qais Ahmad             Afghanistan       20     42       18        9
# Paul Collingwood           England      197   5092      111      181
#
# [394 rows x 5 columns]
