# %%
import pandas as pd

# %%
df = pd.read_csv("LaptopData.csv")

# %%
#  set index
df.set_index("Brand", inplace=True)

# %%
df = df[["Model", "Processor", "RAM_GB",	"Storage_GB", "Screen_Size_inch", "Price_USD"]]
df
# Out:
#             Model    Processor RAM_GB Storage_GB Screen_Size_inch Price_USD
# Brand
# HP        ZenBook  AMD Ryzen 5      8        512             17.3      1099
# Dell      ZenBook  AMD Ryzen 3     32        256             13.3       972
# Asus         Gram     Apple M1     32        128             13.3      1129
# Apple        Gram     Intel i3      4        512             11.6      1304
# Apple      Galaxy     Apple M2      8        256             15.6       953
# ...           ...          ...    ...        ...              ...       ...
# LG       Inspiron     Apple M1     32        128             11.6       992
# Lenovo    ZenBook  AMD Ryzen 7     32        512             11.6      1312
# Toshiba    Aspire     Intel i3     16       1024             14.0      1048
# Dell      ZenBook     Intel i5      8        256             13.3   1209.03
# Toshiba      Gram     Apple M1      4        128             11.6    809.39
#
# [168 rows x 6 columns]

# %% [markdown]
# ## 1 Selecting with a single value
# #### loc[row_label, column_label]

# %%
# get all data about 
df.loc["HP"]
# Out:
#            Model    Processor RAM_GB Storage_GB Screen_Size_inch Price_USD
# Brand
# HP       ZenBook  AMD Ryzen 5      8        512             17.3      1099
# HP        Galaxy  AMD Ryzen 5      4        512             17.3      1315
# HP        Galaxy  AMD Ryzen 3     16        128             17.3       906
# HP       Surface     Intel i3     16        128             15.6       617
# HP        Galaxy  AMD Ryzen 3      8        128             17.3       755
# HP      Pavilion     Intel i7      8       1024             13.3      1041
# HP        Galaxy     Intel i3     32        512             17.3       734
# HP        Aspire  AMD Ryzen 3     32        128             17.3       907
# HP       Surface     Apple M2     32        512             11.6      1068
# HP     Satellite     Apple M1      4        256             14.0      1186
# HP       MacBook  AMD Ryzen 7     16       1024             13.3      1195
# ...
