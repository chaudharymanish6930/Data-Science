# %%
import pandas as pd

# %%
df = pd.read_csv("LaptopData.csv")

# %%
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512             17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256             13.3
# 2       Asus      Gram     Apple M1     32        128             13.3
# 3      Apple      Gram     Intel i3      4        512             11.6
# 4      Apple    Galaxy     Apple M2      8        256             15.6
# ..       ...       ...          ...    ...        ...              ...
# 163       LG  Inspiron     Apple M1     32        128             11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba    Aspire     Intel i3     16       1024             14.0
# 166     Dell   ZenBook     Intel i5      8        256             13.3
# 167  Toshiba      Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 0       NVIDIA MX350      1099
# 1         AMD Radeon       972
# ...

# %% [markdown]
# # duplicated

# %%
df["Brand"].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 163     True
# 164     True
# 165     True
# 166     True
# 167     True
# Name: Brand, Length: 168, dtype: bool

# %%
df.duplicated("Brand")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 163     True
# 164     True
# 165     True
# 166     True
# 167     True
# Length: 168, dtype: bool

# %%
df[df["Brand"].duplicated()]
# Out:
#        Brand      Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 4      Apple     Galaxy     Apple M2      8        256             15.6
# 6         HP     Galaxy  AMD Ryzen 5      4        512             17.3
# 8         HP     Galaxy  AMD Ryzen 3     16        128             17.3
# 11      Dell  Satellite     Apple M2     32        256             15.6
# 12      Dell  Satellite     Intel i5     32        512             14.0
# ..       ...        ...          ...    ...        ...              ...
# 163       LG   Inspiron     Apple M1     32        128             11.6
# 164   Lenovo    ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba     Aspire     Intel i3     16       1024             14.0
# 166     Dell    ZenBook     Intel i5      8        256             13.3
# 167  Toshiba       Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 4       NVIDIA MX350       953
# 6    NVIDIA GTX 1650      1315
# ...

# %%
df[df.duplicated("Brand")]
# Out:
#        Brand      Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 4      Apple     Galaxy     Apple M2      8        256             15.6
# 6         HP     Galaxy  AMD Ryzen 5      4        512             17.3
# 8         HP     Galaxy  AMD Ryzen 3     16        128             17.3
# 11      Dell  Satellite     Apple M2     32        256             15.6
# 12      Dell  Satellite     Intel i5     32        512             14.0
# ..       ...        ...          ...    ...        ...              ...
# 163       LG   Inspiron     Apple M1     32        128             11.6
# 164   Lenovo    ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba     Aspire     Intel i3     16       1024             14.0
# 166     Dell    ZenBook     Intel i5      8        256             13.3
# 167  Toshiba       Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 4       NVIDIA MX350       953
# 6    NVIDIA GTX 1650      1315
# ...

# %%
# duplicate 2 or more 
df.duplicated(["Brand","Model"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 163     True
# 164     True
# 165     True
# 166     True
# 167     True
# Length: 168, dtype: bool

# %%
df[["Brand","Model"]].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 163     True
# 164     True
# 165     True
# 166     True
# 167     True
# Length: 168, dtype: bool

# %%
df[df.duplicated(["Brand","Model"])]
# Out:
#        Brand      Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 8         HP     Galaxy  AMD Ryzen 3     16        128             17.3
# 12      Dell  Satellite     Intel i5     32        512             14.0
# 14     Apple     Galaxy     Intel i7      8       1024             13.3
# 21   Toshiba    Surface     Intel i7      8        256             17.3
# 23     Apple     Aspire  AMD Ryzen 7      4        256             14.0
# ..       ...        ...          ...    ...        ...              ...
# 163       LG   Inspiron     Apple M1     32        128             11.6
# 164   Lenovo    ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba     Aspire     Intel i3     16       1024             14.0
# 166     Dell    ZenBook     Intel i5      8        256             13.3
# 167  Toshiba       Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 8         Integrated       906
# 12   NVIDIA GTX 1650      1048
# ...

# %%
df[df[["Brand","Model"]].duplicated()]
# Out:
#        Brand      Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 8         HP     Galaxy  AMD Ryzen 3     16        128             17.3
# 12      Dell  Satellite     Intel i5     32        512             14.0
# 14     Apple     Galaxy     Intel i7      8       1024             13.3
# 21   Toshiba    Surface     Intel i7      8        256             17.3
# 23     Apple     Aspire  AMD Ryzen 7      4        256             14.0
# ..       ...        ...          ...    ...        ...              ...
# 163       LG   Inspiron     Apple M1     32        128             11.6
# 164   Lenovo    ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba     Aspire     Intel i3     16       1024             14.0
# 166     Dell    ZenBook     Intel i5      8        256             13.3
# 167  Toshiba       Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 8         Integrated       906
# 12   NVIDIA GTX 1650      1048
# ...

# %%
duplicate = df.duplicated(["Brand","Model"])

# %%
df[duplicate].sort_values(["Brand","Model"])
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 130     Acer  Inspiron  AMD Ryzen 5      4        256             17.3
# 65      Acer  Pavilion  AMD Ryzen 5      4        512             15.6
# 88      Acer  Pavilion  AMD Ryzen 5     32       1024             17.3
# 125     Acer  Pavilion     Apple M2      4       1024             15.6
# 156     Acer  Pavilion  AMD Ryzen 5      4        512             15.6
# ..       ...       ...          ...    ...        ...              ...
# 21   Toshiba   Surface     Intel i7      8        256             17.3
# 110  Toshiba   Surface  AMD Ryzen 3      4        128             17.3
# 112  Toshiba   Surface     Intel i7      8        256             17.3
# 89   Toshiba   ZenBook  AMD Ryzen 5     16        512             14.0
# 136  Toshiba   ZenBook  AMD Ryzen 7      4        256             14.0
#
#             Graphics Price_USD
# 130       Integrated      1039
# 65        Integrated      1271
# ...
