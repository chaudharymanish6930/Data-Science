# %%
import pandas as pd

# %%
df = pd.read_csv("LaptopData.csv")

# %%
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512             17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256             13.3
# 2       Asus      Gram     Apple M1     32        128             13.3
# 3      Apple      Gram     Intel i3      4        512             11.6
# 4      Apple    Galaxy     Apple M2      8        256             15.6
# ..       ...       ...          ...    ...        ...              ...
# 163       LG  Inspiron     Apple M1     32        128             11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba    Aspire     Intel i3     16       1024             14.0
# 166     Dell   ZenBook     Intel i5      8        256             13.3
# 167  Toshiba      Gram     Apple M1      4        128             11.6
#
#             Graphics Price_USD
# 0       NVIDIA MX350      1099
# 1         AMD Radeon       972
# ...

# %%
import numpy as np

# %%
# convert the string type into the int type
df["Price_USD"] = pd.to_numeric(df["Price_USD"], errors="coerce")

# %%
# Define conditions
conditions = [
    df["Price_USD"] > 3000,
    (df["Price_USD"] > 2000) & (df["Price_USD"] <= 3000),
    (df["Price_USD"] > 800) & (df["Price_USD"] <= 2000),
    df["Price_USD"] <= 800
]

# Define values
values = ["Too Expensive", "Expensive", "Affordable", "Cheap"]

# Apply np.select
df["Price_Category"] = np.select(conditions, values, default="Unknown")

# %%
# shows the dataframe
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512             17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256             13.3
# 2       Asus      Gram     Apple M1     32        128             13.3
# 3      Apple      Gram     Intel i3      4        512             11.6
# 4      Apple    Galaxy     Apple M2      8        256             15.6
# ..       ...       ...          ...    ...        ...              ...
# 163       LG  Inspiron     Apple M1     32        128             11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba    Aspire     Intel i3     16       1024             14.0
# 166     Dell   ZenBook     Intel i5      8        256             13.3
# 167  Toshiba      Gram     Apple M1      4        128             11.6
#
#             Graphics  Price_USD Price_Category
# 0       NVIDIA MX350    1099.00     Affordable
# ...

# %%
df["Price_USD"].value_counts()
# Out:
# Price_USD
# 907.00     4
# 1048.00    4
# 906.00     4
# 953.00     4
# 1072.00    4
#           ..
# 728.58     1
# 1497.59    1
# 1164.70    1
# 1076.20    1
# 1305.56    1
# Name: count, Length: 84, dtype: int64

# %%
df["Price_Category1"] = np.select(conditions, values, default="Unknown")

# %%
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512             17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256             13.3
# 2       Asus      Gram     Apple M1     32        128             13.3
# 3      Apple      Gram     Intel i3      4        512             11.6
# 4      Apple    Galaxy     Apple M2      8        256             15.6
# ..       ...       ...          ...    ...        ...              ...
# 163       LG  Inspiron     Apple M1     32        128             11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512             11.6
# 165  Toshiba    Aspire     Intel i3     16       1024             14.0
# 166     Dell   ZenBook     Intel i5      8        256             13.3
# 167  Toshiba      Gram     Apple M1      4        128             11.6
#
#             Graphics  Price_USD Price_Category Price_Category1
# ...

# %%
df["Price_Category1"].value_counts()
# Out:
# Price_Category1
# Affordable    138
# Cheap          29
# Unknown         1
# Name: count, dtype: int64

# %% [markdown]
# ## Exercise
# #### Create an array based on multiple sscreen size tier (+2 choices)
# #### create "conditions" and "values" Variable

# %%
df["Screen_Size_inch"] = pd.to_numeric(df["Screen_Size_inch"], errors="coerce") 
conditions = [
    df["Screen_Size_inch"] <= 12,
    (df["Screen_Size_inch"] >12) & (df["Screen_Size_inch"]<=14),
    (df["Screen_Size_inch"] > 14) & (df["Screen_Size_inch"]<=16),
    df["Screen_Size_inch"]>16,
]
values = ["too small", "small", "big", "too big"]

df["Screen_size_conddition"] = np.select(conditions, values,  default="Unknown")

# %%
df
# Out:
#        Brand     Model    Processor RAM_GB Storage_GB  Screen_Size_inch  \
# 0         HP   ZenBook  AMD Ryzen 5      8        512              17.3
# 1       Dell   ZenBook  AMD Ryzen 3     32        256              13.3
# 2       Asus      Gram     Apple M1     32        128              13.3
# 3      Apple      Gram     Intel i3      4        512              11.6
# 4      Apple    Galaxy     Apple M2      8        256              15.6
# ..       ...       ...          ...    ...        ...               ...
# 163       LG  Inspiron     Apple M1     32        128              11.6
# 164   Lenovo   ZenBook  AMD Ryzen 7     32        512              11.6
# 165  Toshiba    Aspire     Intel i3     16       1024              14.0
# 166     Dell   ZenBook     Intel i5      8        256              13.3
# 167  Toshiba      Gram     Apple M1      4        128              11.6
#
#             Graphics  Price_USD Price_Category Price_Category1  \
# ...

# %%
df.values_counts("Screen_size_conddition")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16720\3375914048.py in ?()
# ----> 1 df.values_counts("Screen_size_conddition")
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'values_counts'
